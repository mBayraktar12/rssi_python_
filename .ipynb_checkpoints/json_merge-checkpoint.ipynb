# %%
import json
import os
import glob
import pandas as pd
import numpy as np

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,"*json"))
        for f in files:
            all_files.append(os.path.abspath(f))
    return all_files

# %%
beacon_data = get_files("rssi_data")
filepath = beacon_data[0]

# %%
df = pd.read_json(filepath, lines = True)
print(df.head())
# Out:
#                         collectedDataWithIndoorLevel  \
# 0  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
#
#                                           deviceInfo
# 0  {'androidBuildVersion': {'baseOS': '', 'sdkInt...

# %%
data_list = []
for data in beacon_data:
    with open(data) as doc:
        exp = json.load(doc)
        data_list.append(exp)

# %%
print(data_list[:5])
# Out:
# [{'collectedDataWithIndoorLevel': {'pointModel': {'indoorLevel': 0, 'lat': 36.89814073078286, 'long': 30.64733899614521}, 'dataModel': {'beaconDataList': [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.33, 'proximity': 'Near', 'rssi': -70, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 3.07, 'proximity': 'Far', 'rssi': -74, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.4, 'proximity': 'Far', 'rssi': -74, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.5, 'proximity': 'Near', 'rssi': -83, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.28, 'proximity': 'Near', 'rssi': -69, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 3.05, 'proximity': 'Far', 'rssi': -77, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.4, 'proximity': 'Far', 'rssi': -86, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.44, 'proximity': 'Near', 'rssi': -69, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.41, 'proximity': 'Near', 'rssi': -96, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 2.93, 'proximity': 'Near', 'rssi': -75, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.53, 'proximity': 'Far', 'rssi': -80, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.42, 'proximity': 'Near', 'rssi': -65, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.42, 'proximity': 'Near', 'rssi': -71, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 2.85, 'proximity': 'Near', 'rssi': -76, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.61, 'proximity': 'Far', 'rssi': -78, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.37, 'proximity': 'Near', 'rssi': -64, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null ...

# %%
df2 = pd.DataFrame(data_list)
df2.head()
# Out:
#                         collectedDataWithIndoorLevel  \
# 0  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 1  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 2  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 3  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 4  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
#
#                                           deviceInfo
# 0  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 1  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 2  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 3  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 4  {'androidBuildVersion': {'baseOS': '', 'sdkInt...

# %%
df2.iloc[:5].to_json("df2_indent.json",orient = "records",indent = 5)

# %%
df3 = pd.read_json("df2_indent.json")
df3.head()
# Out:
#                         collectedDataWithIndoorLevel  \
# 0  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 1  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 2  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 3  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 4  {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
#
#                                           deviceInfo
# 0  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 1  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 2  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 3  {'androidBuildVersion': {'baseOS': '', 'sdkInt...
# 4  {'androidBuildVersion': {'baseOS': '', 'sdkInt...

# %%
print(df2["collectedDataWithIndoorLevel"])
# Out:
# 0     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 1     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 2     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 3     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 4     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 5     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 6     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 7     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 8     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 9     {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 10    {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# 11    {'pointModel': {'indoorLevel': 0, 'lat': 36.89...
# Name: collectedDataWithIndoorLevel, dtype: object

# %%
rssi = df2.iloc[:1].values
print(rssi)
# Out:
# [[{'pointModel': {'indoorLevel': 0, 'lat': 36.89814073078286, 'long': 30.64733899614521}, 'dataModel': {'beaconDataList': [{'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.33, 'proximity': 'Near', 'rssi': -70, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 3.07, 'proximity': 'Far', 'rssi': -74, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.4, 'proximity': 'Far', 'rssi': -74, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.5, 'proximity': 'Near', 'rssi': -83, 'txPower': -60, 'scanTime': '22 April 2022 07:16:26 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.28, 'proximity': 'Near', 'rssi': -69, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 3.05, 'proximity': 'Far', 'rssi': -77, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.4, 'proximity': 'Far', 'rssi': -86, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.44, 'proximity': 'Near', 'rssi': -69, 'txPower': -60, 'scanTime': '22 April 2022 07:16:27 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.41, 'proximity': 'Near', 'rssi': -96, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 2.93, 'proximity': 'Near', 'rssi': -75, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.53, 'proximity': 'Far', 'rssi': -80, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.42, 'proximity': 'Near', 'rssi': -65, 'txPower': -60, 'scanTime': '22 April 2022 07:16:29 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-902d-f6a8743d178f', 'macAddress': 'A0:E6:F8:40:28:E8', 'major': 1000, 'minor': 1056, 'distance': 2.42, 'proximity': 'Near', 'rssi': -71, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'edae28d6-489b-446c-af10-6663fb553136', 'macAddress': 'A0:E6:F8:40:3B:86', 'major': 1000, 'minor': 1027, 'distance': 2.85, 'proximity': 'Near', 'rssi': -76, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D9:29', 'major': 1000, 'minor': 1143, 'distance': 3.61, 'proximity': 'Far', 'rssi': -78, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': 'a849c1ed-ad3c-4e8f-a571-089dae67cccc', 'macAddress': 'A0:E6:F8:3F:D8:68', 'major': 1000, 'minor': 1168, 'distance': 2.37, 'proximity': 'Near', 'rssi': -64, 'txPower': -60, 'scanTime': '22 April 2022 07:16:30 PM'}, {'name': 'null', 'uuid': '383e5cf9-6c79-4e7b-9 ...
#   {'androidBuildVersion': {'baseOS': '', 'sdkInt': 28, 'release': '9', 'codename': 'REL', 'incremental': 'G955FXXUCDUD1', 'previewSdkInt': 0, 'securityPatch': '2021-04-01'}, 'board': 'universal8895', 'bootloader': 'G955FXXUCDUD1', 'brand': 'samsung', 'device': 'dream2lte', 'display': 'PPR1.180610.011.G955FXXUCDUD1', 'fingerprint': 'samsung/dream2ltexx/dream2lte:9/PPR1.180610.011/G955FXXUCDUD1:user/release-keys', 'hardware': 'samsungexynos8895', 'systemFeatures': ['android.hardware.sensor.proximity', 'com.samsung.android.sdk.camera.processor', 'com.samsung.feature.aodservice_v06', 'com.sec.feature.motionrecognition_service', 'com.sec.feature.cover.sview', 'com.samsung.android.camera.iris', 'android.hardware.sensor.accelerometer', 'android.hardware.faketouch', 'com.samsung.feature.device_category_phone_high_end', 'android.hardware.usb.accessory', 'com.samsung.feature.hdr_capable', 'android.software.backup', 'android.hardware.touchscreen', 'android.hardware.touchscreen.multitouch', 'android.software.print', 'android.software.activities_on_secondary_displays', 'com.sec.feature.nfc_authentication_cover', 'android.hardware.sensor.heartrate', 'com.sec.feature.nfc_authentication', 'android.software.voice_recognizers', 'android.software.picture_in_picture', 'android.hardware.fingerprint', 'com.samsung.android.knox.knoxsdk', 'android.hardware.sensor.gyroscope', 'com.sec.feature.slocation', 'android.software.cant_save_state', 'com.samsung.android.sdk.camera.processor.haze', 'com.samsung.feature.device_category_phone', 'android.hardware.opengles.aep', 'com.sec.feature.fingerprint_manager_service', 'com.sec.feature.sensorhub', 'com.sec.feature.overlaymagnifier', 'android.hardware.bluetooth', 'android.hardware.camera.autofocus', 'android.hardware.telephony.gsm', 'com.sec.feature.cocktailpanel', 'com.samsung.android.bio.face', 'android.software.sip.voip', 'com.sec.feature.saccessorymanager', 'android.hardware.vr.high_performance', 'com.samsung.feature.samsung_experience_mobile', 'android.hardware.usb.host', 'android.hardware.audio.output', 'android.software.verified_boot', 'android.hardware.camera.flash', 'android.hardware.camera.front', 'android.hardware.sensor.hifi_sensors', 'com.samsung.feature.hmt', 'android.hardware.screen.portrait', 'android.hardware.nfc', 'com.google.android.feature.TURBO_PRELOAD', 'com.sec.android.mdm', 'com.samsung.feature.ipsgeofence', 'com.nxp.mifare', 'com.sec.feature.cover.clearcover', 'android.hardware.sensor.stepdetector', 'android.software.home_screen', 'com.sec.feature.barcode_emulator', 'android.hardware.microphone', 'android.software.autofill', 'com.samsung.android.sdk.camera.processor.effect', 'android.software.vr.mode', 'android.hardware.bluetooth_le', 'com.sec.feature.edge_v03', 'android.hardware.sensor.compass', 'android.hardware.touchscreen.multitouch.jazzhand', 'android.hardware.sensor.barometer', 'android.software.app_widgets', 'android.software.input_methods', 'android.hardware.sensor.light', 'android.hardware.vulkan.version', 'android.software.companion_device_setup', 'com.samsung.feature.galaxyfinder_v7', 'android.software.device_admin', 'com.sec.android.secimaging.faceAR', 'android.hardware.camera', 'android.hardware.screen.landscape', 'android.hardware.ram.normal', 'com.samsung.feature.samsungpositioning.snlp', 'com.samsung.android.authfw', 'com.samsung.android.api.version.2402', 'com.samsung.android.api.version.2403', 'com.samsung.android.api.version.2501', 'com.samsung.android.api.version.2502', 'com.samsung.android.api.version.2601', 'com.samsung.android.api.version.2701', 'com.samsung.android.api.version.2801', 'com.sec.feature.cover', 'com.sec.feature.findo', 'android.software.managed_users', 'com.sec.feature.nsflp', 'android.software.webview', 'android.hardware.sensor.stepcounter', 'android.hardware.camera.capability.manual_post_processing', 'com.sec.feature.spo2', 'android.hardware.camera.any', 'com.samsung.android.sdk.camera.processor.dof', 'com.samsung.android.sdk.camera.processor.gif' ...

# %%
print(type(rssi))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(df2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
