# %%
import csv
import json

# %%
with open('df2_indent.json') as data_file:
    data = json.load(data_file)

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
for i in range(len(data)):
    print(data[0]["pointModel"][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
#       1 for i in range(len(data)):
# ----> 2     print(data[0]["beaconDataList"][i])
#
# KeyError: 'beaconDataList'
